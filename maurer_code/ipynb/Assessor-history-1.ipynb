# %%
import time
import zipfile
import csv

# %%
path = '/Volumes/Seagate1/DataQuick/Assessor History/'
zname = 'AH_2014.ZIP'
fname = 'AH_2014.TXT'

# %%
with zipfile.ZipFile(path+zname) as z:
    with z.open(fname) as f:
        line = f.readline()
        line = f.readline()
        print len(line), "characters"
        print
        print line.split('\t')
# Out:
# 1598 characters
#
# ['29129595    47          00109306                           0010930600                         WILLIAMS,JENNIFER D                               JENNIFER                                          D                   WILLIAMS                                                                                                             0                                                                                                                                                                                                                JTBAKERSFIELD                   C018            2617                1804     BAY                                     ST                  93301       BAKERSFIELD                                       C018            2617                1804     CABAY                                               ST                  93301       YRSFR7           2013   156060      41616       114444      0           0           0           0           0           0           Y7000         0            0            0            0           T7000        2012   1824.90                                   0      1327       0      0      Y   1327        0           0           0           0           Y   Y 360    9 6660.0000                                1.75                                     0      0      0      0      0      0      3      5      1    1             1327        1327        1             1948   1948   20101221    159000      0000178190          0                               146479      0    0  2014        1           2014-01-14 163982      163982\r\n']

# %%
for y in range(2004,2015):
    zname = 'AH_' + str(y) + '.ZIP'
    fname = 'AH_' + str(y) + '.TXT'
    with zipfile.ZipFile(path+zname) as z:
        with z.open(fname) as f:
            line = f.readline()
            print len(line), "characters"
# Out:
# 1597 characters
# 1597 characters
# 1597
#  characters
# 1597 characters
# 1597 characters
# 1597 characters
# 1597
#  characters
# 1598 characters
# 1598 characters
# 1598
#  characters
# 1598 characters

# %%
fields = ["SA_PROPERTY_ID",
"AH_HISTORY_YR",
"AH_HISTORY_YR_VERSION",
"SA_SCM_ID",
"MM_STATE_CODE",
"MM_MUNI_NAME",
"MM_FIPS_STATE_CODE",
"MM_FIPS_MUNI_CODE",
"MM_FIPS_COUNTY_NAME",
"SA_PARCEL_NBR_PRIMARY",
"SA_PARCEL_NBR_PREVIOUS",
"SA_OWNER_1",
"SA_OWNER_1_FIRST",
"SA_OWNER_1_MID",
"SA_OWNER_1_LAST",
"SA_OWNER_1_SUF",
"SA_OWNER_1_SP_FIRST",
"SA_OWNER_1_SP_MID",
"SA_OWNER_1_SP_SUF",
"SA_OWNER_1_GROUP",
"SA_OWNER_1_ET_FLAG",
"SA_OWNER_1_TRUST_FLAG",
"SA_OWNER_1_TYPE",
"SA_OWNER_2",
"SA_OWNER_2_FIRST",
"SA_OWNER_2_MID",
"SA_OWNER_2_LAST",
"SA_OWNER_2_SUF",
"SA_OWNER_2_SP_FIRST",
"SA_OWNER_2_SP_MID",
"SA_OWNER_2_SP_SUF",
"SA_OWNER_2_GROUP",
"SA_OWNER_2_ET_FLAG",
"SA_OWNER_2_TRUST_FLAG",
"SA_OWNER_2_TYPE",
"SA_OWNERSHIP_STATUS_CODE",
"SA_SITE_HOUSE_NBR",
"SA_SITE_FRACTION",
"SA_SITE_DIR",
"SA_SITE_STREET_NAME",
"SA_SITE_SUF",
"SA_SITE_POST_DIR",
"SA_SITE_UNIT_PRE",
"SA_SITE_UNIT_VAL",
"SA_SITE_CITY",
"SA_SITE_STATE",
"SA_SITE_ZIP",
"SA_SITE_PLUS_4",
"SA_SITE_CRRT",
"SA_MAIL_HOUSE_NBR",
"SA_MAIL_FRACTION",
"SA_MAIL_DIR",
"SA_MAIL_STREET_NAME",
"SA_MAIL_SUF",
"SA_MAIL_POST_DIR",
"SA_MAIL_UNIT_PRE",
"SA_MAIL_UNIT_VAL",
"SA_MAIL_CITY",
"SA_MAIL_STATE",
"SA_MAIL_ZIP",
"SA_MAIL_PLUS_4",
"SA_MAIL_CRRT",
"SA_SITE_MAIL_SAME",
"OWNER_OCCUPANCY_CODE",
"USE_CODE_STD",
"ASSR_YEAR",
"SA_VAL_ASSD",
"SA_VAL_ASSD_LAND",
"SA_VAL_ASSD_IMPRV",
"SA_APPRAISE_VAL",
"SA_VAL_APPRAISE_LAND",
"SA_VAL_APPRAISE_IMPRV",
"SA_IMPRV_PCT_APPRAISE",
"SA_VAL_MARKET",
"SA_VAL_MARKET_LAND",
"SA_VAL_MARKET_IMPRV",
"SA_EXEMP_FLAG_1",
"SA_EXEMP_VAL_1",
"SA_EXEMP_FLAG_2",
"SA_EXEMP_VAL_2",
"SA_EXEMP_FLAG_3",
"SA_EXEMP_VAL_3",
"SA_EXEMP_FLAG_4",
"SA_EXEMP_VAL_4",
"SA_EXEMP_FLAG_5",
"SA_EXEMP_VAL_5",
"SA_EXEMP_FLAG_6",
"SA_EXEMP_VAL_6",
"TAXYEAR",
"SA_TAX_VAL",
"SA_ARCHITECTURE_CODE",
"SA_ATTIC_SQFT",
"SA_BLDG_SQFT",
"SA_BSMT_2_CODE",
"SA_BSMT_FIN_SQFT",
"SA_BSMT_UNFIN_SQFT",
"SA_COOL_CODE",
"SA_EXTERIOR_1_CODE",
"SA_FIN_SQFT_1",
"SA_FIN_SQFT_2",
"SA_FIN_SQFT_3",
"SA_FIN_SQFT_4",
"SA_FIN_SQFT_TOT",
"SA_FIREPLACE_CODE",
"SA_FOUNDATION_CODE",
"SA_GRG_1_CODE",
"SA_GRG_SQFT_1",
"SA_HEAT_CODE",
"SA_LOTSIZE",
"SA_NBR_BATH",
"SA_NBR_BATH_1QTR",
"SA_NBR_BATH_HALF",
"SA_NBR_BATH_3QTR",
"SA_NBR_BATH_FULL",
"SA_NBR_BATH_BSMT_HALF",
"SA_NBR_BATH_BSMT_FULL",
"SA_NBR_BEDRMS",
"SA_NBR_RMS",
"SA_NBR_STORIES",
"SA_NBR_UNITS",
"SA_PATIO_PORCH_CODE",
"SA_POOL_CODE",
"SA_PRIVACY_CODE",
"SA_ROOF_CODE",
"SA_SQFT",
"SA_SQFT_ASSR_TOT",
"SA_SQFT_DQ",
"SA_STRUCTURE_CODE",
"SA_YR_BLT",
"SA_YR_BLT_EFFECT",
"SA_DATE_TRANSFER",
"SA_VAL_TRANSFER",
"SA_DOC_NBR_FMT",
"SA_DATE_NOVAL_TRANSFER",
"SA_DOC_NBR_NOVAL",
"PROCESS_ID",
"SA_INACTIVE_PARCEL_FLAG",
"SA_SHELL_PARCEL_FLAG",
"FILLER"]

# %%
field_lengths = [12, 4, 2, 12, 2, 24, 5, 7, 35, 35, 35, 50, 50, 20, 50, 5, 20, 20, 5, 15,
1, 1, 1, 50, 50, 20, 20, 5, 20, 20, 5, 15, 1, 1, 1, 2, 20, 10, 2, 40, 4,
2, 10, 6, 30, 2, 12, 7, 4, 20, 10, 2, 50, 4, 2, 10, 6, 50, 2, 12, 7, 4,
1, 2, 4, 4, 12, 12, 12, 12, 12, 12, 8, 12, 12, 12, 1, 12, 1, 12, 1, 12,
1, 12, 1, 12, 1, 12, 4, 12, 1, 7, 7, 2, 7, 7, 2, 2, 12, 12, 12, 12, 12,
2, 2, 2, 7, 2, 19, 8, 7, 7, 7, 7, 7, 7, 7, 7, 5, 7, 2, 2, 1, 2, 12, 12,
12, 2, 4, 4, 12, 12, 20, 12, 20, 12, 1, 1, 40,]

# %%
arr = []
pos = 0

print repr(line)
print

for flen in field_lengths:
    arr.append(line[pos:pos+flen].rstrip(' '))
    pos += flen

for i, lab in enumerate(fields):
    print str(i+1), fields[i], "//", arr[i]
# Out:
# '29129594    47          00109305                           0010930500                         WAGSTAFFE,CHRISTINA                               CHRISTINA                                                             WAGSTAFFE                                                                                                            0                                                                                                                                                                                                                SWBAKERSFIELD                   C018            2621                1804     BAY                                     ST                  93301       BAKERSFIELD                                       C018            2621                1804     CABAY                                               ST                  93301       YRSFR7           2013   114000      29000       85000       0           0           0           0           0           0           Y7000         0            0            0            0           T7000        2012   1645.75                                   0      1200       0      0          1200        0           0           0           0           1   Y 360    9 .0000                                    1.00                                     0      0      0      0      0      0      2      0      1    1      2      1200        1200        1             1948   1948   20080908    170000      0000142102          0                               146479      0    0  2014        1           2014-01-14 163982      163982\r\n'
#
# 1 SA_PROPERTY_ID // 29129594
# 2 AH_HISTORY_YR // 47
# 3 AH_HISTORY_YR_VERSION //
# 4 SA_SCM_ID //       001093
# 5 MM_STATE_CODE // 05
# 6 MM_MUNI_NAME //
# 7 MM_FIPS_STATE_CODE //    00
# 8 MM_FIPS_MUNI_CODE // 1093050
# 9 MM_FIPS_COUNTY_NAME // 0                         WAGSTAFFE
# 10 SA_PARCEL_NBR_PRIMARY // ,CHRISTINA
# 11 SA_PARCEL_NBR_PREVIOUS //       CHRISTINA
# 12 SA_OWNER_1 //                                          WAGSTAFFE
# 13 SA_OWNER_1_FIRST //
# 14 SA_OWNER_1_MID //
# 15 SA_OWNER_1_LAST //                                       0
# 16 SA_OWNER_1_SUF //
# 17 SA_OWNER_1_SP_FIRST //
# 18 SA_OWNER_1_SP_MID //
# 19 SA_OWNER_1_SP_SUF //
# 20 SA_OWNER_1_GROUP //
# 21 SA_OWNER_1_ET_FLAG //
# 22 SA_OWNER_1_TRUST_FLAG //
# 23 SA_OWNER_1_TYPE //
# 24 SA_OWNER_2 //
# 25 SA_OWNER_2_FIRST //
# 26 SA_OWNER_2_MID //
# 27 SA_OWNER_2_LAST //          SWBAKERSFIE
# 28 SA_OWNER_2_SUF // LD
# 29 SA_OWNER_2_SP_FIRST //                 C018
# 30 SA_OWNER_2_SP_MID //             2621
# 31 SA_OWNER_2_SP_SUF //
# 32 SA_OWNER_2_GROUP //        1804
# 33 SA_OWNER_2_ET_FLAG //
# 34 SA_OWNER_2_TRUST_FLAG // B
# 35 SA_OWNER_2_TYPE // A
# 36 SA_OWNERSHIP_STATUS_CODE // Y
# 37 SA_SITE_HOUSE_NBR //
# 38 SA_SITE_FRACTION //
# 39 SA_SITE_DIR //
# 40 SA_SITE_STREET_NAME //     ST                  93301       BAKE
# 41 SA_SITE_SUF // RSFI
# 42 SA_SITE_POST_DIR // EL
# 43 SA_SITE_UNIT_PRE // D
# 44 SA_SITE_UNIT_VAL //
# 45 SA_SITE_CITY //                         C018
# 46 SA_SITE_STATE //
# 47 SA_SITE_ZIP //         2621
# 48 SA_SITE_PLUS_4 //
# 49 SA_SITE_CRRT //
# 50 SA_MAIL_HOUSE_NBR //      1804     CABAY
# 51 SA_MAIL_FRACTION //
# 52 SA_MAIL_DIR //
# 53 SA_MAIL_STREET_NAME //                                   ST
# 54 SA_MAIL_SUF //
# 55 SA_MAIL_POST_DIR // 93
# 56 SA_MAIL_UNIT_PRE // 301
# 57 SA_MAIL_UNIT_VAL // YRSFR7
# 58 SA_MAIL_CITY //            2013   114000      29000       85000
# 59 SA_MAIL_STATE //
# 60 SA_MAIL_ZIP //   0
# 61 SA_MAIL_PLUS_4 //   0
# 62 SA_MAIL_CRRT //
# 63 SA_SITE_MAIL_SAME //
# 64 OWNER_OCCUPANCY_CODE //
# 65 USE_CODE_STD // 0
# 66 ASSR_YEAR //
# 67 SA_VAL_ASSD //     0
# 68 SA_VAL_ASSD_LAND //     0
# 69 SA_VAL_ASSD_IMPRV //     0
# 70 SA_APPRAISE_VAL //     Y7000
# 71 SA_VAL_APPRAISE_LAND //       0
# 72 SA_VAL_APPRAISE_IMPRV //        0
# 73 SA_IMPRV_PCT_APPRAISE //
# 74 SA_VAL_MARKET // 0
# 75 SA_VAL_MARKET_LAND //  0
# 76 SA_VAL_MARKET_IMPRV //  T7000
# 77 SA_EXEMP_FLAG_1 //
# 78 SA_EXEMP_VAL_1 //  2012   1645
# 79 SA_EXEMP_FLAG_2 // .
# 80 SA_EXEMP_VAL_2 // 75
# 81 SA_EXEMP_FLAG_3 //
# 82 SA_EXEMP_VAL_3 //
# 83 SA_EXEMP_FLAG_4 //
# 84 SA_EXEMP_VAL_4 //            0
# 85 SA_EXEMP_FLAG_5 //
# 86 SA_EXEMP_VAL_5 //      1200
# 87 SA_EXEMP_FLAG_6 //
# 88 SA_EXEMP_VAL_6 //    0      0
# 89 TAXYEAR //
# 90 SA_TAX_VAL //      1200
# 91 SA_ARCHITECTURE_CODE //
# 92 SA_ATTIC_SQFT //     0
# 93 SA_BLDG_SQFT //
# 94 SA_BSMT_2_CODE //
# 95 SA_BSMT_FIN_SQFT // 0
# 96 SA_BSMT_UNFIN_SQFT //      0
# 97 SA_COOL_CODE //
# 98 SA_EXTERIOR_1_CODE //
# 99 SA_FIN_SQFT_1 //       0
# 100 SA_FIN_SQFT_2 //       1   Y
# 101 SA_FIN_SQFT_3 // 360    9 .00
# 102 SA_FIN_SQFT_4 // 00
# 103 SA_FIN_SQFT_TOT //
# 104 SA_FIREPLACE_CODE //
# 105 SA_FOUNDATION_CODE //
# 106 SA_GRG_1_CODE //
# 107 SA_GRG_SQFT_1 //
# 108 SA_HEAT_CODE //  1
# 109 SA_LOTSIZE // .00
# 110 SA_NBR_BATH //
# 111 SA_NBR_BATH_1QTR //
# 112 SA_NBR_BATH_HALF //       0
# 113 SA_NBR_BATH_3QTR //       0
# 114 SA_NBR_BATH_FULL //       0
# 115 SA_NBR_BATH_BSMT_HALF //       0
# 116 SA_NBR_BATH_BSMT_FULL //       0
# 117 SA_NBR_BEDRMS //       0
# 118 SA_NBR_RMS //       2
# 119 SA_NBR_STORIES //
# 120 SA_NBR_UNITS //  0
# 121 SA_PATIO_PORCH_CODE //  1
# 122 SA_POOL_CODE //
# 123 SA_PRIVACY_CODE //
# 124 SA_ROOF_CODE //  1
# 125 SA_SQFT //       2
# 126 SA_SQFT_ASSR_TOT //  1200
# 127 SA_SQFT_DQ //  1200
# 128 SA_STRUCTURE_CODE //  1
# 129 SA_YR_BLT //
# 130 SA_YR_BLT_EFFECT //
# 131 SA_DATE_TRANSFER //      1948
# 132 SA_VAL_TRANSFER // 1948   20080
# 133 SA_DOC_NBR_FMT // 908    170000      0
# 134 SA_DATE_NOVAL_TRANSFER // 000142102
# 135 SA_DOC_NBR_NOVAL //        0
# 136 PROCESS_ID //
# 137 SA_INACTIVE_PARCEL_FLAG //
# 138 SA_SHELL_PARCEL_FLAG //
# 139 FILLER //      146479      0    0  2014        1

# %%
# Save to CSV

t0 = time.time()
data = []

with zipfile.ZipFile(path+zname) as z:
    with z.open(fname) as f:
        for i in range(10000):
            line = f.readline()
            pos = 0
            arr = []
            for flen in field_lengths:
                arr.append(line[pos:pos+flen].rstrip(' '))
                pos += flen
            data.append(arr)

print time.time() - t0
print len(data)
# Out:
# 2.00152587891
# 10000

# %%
import csv
with open(path+'ARB_ASSR_SAMPLE.csv', 'wb') as f:
    writer = csv.writer(f)
    writer.writerow(fields)
    writer.writerows(data)
